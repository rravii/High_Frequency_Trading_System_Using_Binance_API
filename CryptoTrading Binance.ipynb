# %% [markdown]
# ### Libraries

# %%
from binance.client import Client
import pandas as pd
import ta
import datetime
import time

# %% [markdown]
# ### Credentials

# %%
api_key = "binance_api_key"
api_secret = "binance_secret_key"

# %% [markdown]
# ### Pulling Crypto Price Data

# %%
client = Client(api_key,api_secret, testnet=True)

# %%
symbol = 'BTCUSDT'

# %%
pd.DataFrame(client.get_historical_klines('BTCUSDT' , '15m', '3000 minutes UTC'))
# Out:
#                 0               1               2               3   \
# 0    1684423800000  27119.66000000  50000.00000000   9960.10000000
# 1    1684424700000  27139.07000000  29000.00000000  13569.90000000
# 2    1684425600000  27086.69000000  29024.90000000  25000.00000000
# 3    1684426500000  27057.32000000  29000.00000000  24910.60000000
# 4    1684427400000  27033.53000000  27142.00000000  26758.00000000
# ..             ...             ...             ...             ...
# 195  1684599300000  26941.04000000  26941.04000000  26920.63000000
# 196  1684600200000  26931.08000000  26932.00000000  26918.83000000
# 197  1684601100000  26923.15000000  26923.16000000  26913.22000000
# 198  1684602000000  26918.46000000  26929.36000000  26917.68000000
# 199  1684602900000  26925.43000000  26925.45000000  26918.07000000
#
#                  4             5              6                 7     8   \
# 0    27139.33000000   93.54912300  1684424699999  2539568.80403616  3017
# 1    27086.56000000  110.85593600  1684425599999  3003959.34413831  2459
# 2    27057.94000000  113.76933100  1684426499999  3080811.96534037  2816
# 3    27031.55000000   90.40236300  1684427399999  2445212.37491389  2094
# 4    27102.52000000   80.49941400  1684428299999  2178640.81494047  1955
# ..              ...           ...            ...               ...   ...
# 195  26931.07000000   27.94597900  1684600199999   752599.32040207   842
# 196  26923.15000000   21.73213400  1684601099999   585124.10299767   644
# 197  26918.46000000   12.93294300  1684601999999   348112.11652606   424
# 198  26925.43000000   23.22837300  1684602899999   625398.73120790   776
# 199  26924.02000000   11.19529400  1684603799999   301395.76016009   389
#
#               9                 10 11
# 0    52.31112200  1421464.36251065  0
# 1    56.42707600  1530410.42844863  0
# 2    64.01864400  1733924.82760658  0
# 3    49.13869100  1329271.90425130  0
# 4    47.45263600  1284297.30537925  0
# ..           ...               ... ..
# 195  12.86653200   346499.07347337  0
# 196  11.00720400   296355.90188705  0
# 197   7.85227300   211352.91804529  0
# 198  16.32273100   439468.73555667  0
# 199   5.19446300   139842.38999668  0
#
# [200 rows x 12 columns]

# %%
def getdata(symbol):
    frame = pd.DataFrame(client.get_historical_klines(symbol, '15m', '3000 minutes UTC'))
    frame = frame.iloc[:, 0:5]
    frame.columns = ['Time', 'Open', 'High', 'Low', 'Close']
    frame = frame.set_index('Time')
    frame.index = pd.to_datetime(frame.index, unit='ms')
    frame = frame.astype(float)
    return frame

# %%
df = getdata(symbol)

# %% [markdown]
# ### Indicator Calculation/ Buy Condition

# %%
def indicators(df):
    df['SMA_200'] = ta.trend.sma_indicator(df['Close'], window=200)
    df['stochrsi_k'] = ta.momentum.stochrsi_k(df['Close'], window=10)
    df.dropna(inplace=True)
    df['Buy'] = (df['Close'] > df['SMA_200']) & (df['stochrsi_k'] < 0.05)
    return df

# %%
indicators(df)
# Out:
#                          Open      High       Low     Close      SMA_200  \
# Time
# 2023-05-20 17:15:00  26925.43  26925.45  26918.07  26924.01  26866.48855
#
#                      stochrsi_k    Buy
# Time
# 2023-05-20 17:15:00    0.106723  False

# %%
float(client.get_symbol_ticker(symbol=symbol)['price']) * 0.97
# Out:
# 26116.260599999998

# %% [markdown]
# ### Buy Limit Order: Helper Function

# %%
def pricecalc(symbol, limit=0.97):
    raw_price = float(client.get_symbol_ticker(symbol=symbol)['price'])
    dec_len = len(str(raw_price).split('.')[1])
    price = raw_price * limit
    return round(price, dec_len)

def quantitycalc(symbol, investment):
    info = client.get_symbol_info(symbol=symbol)
    Lotsize = float([i for i in info['filters'] if i['filterType'] == 'LOT_SIZE'][0]['minQty'])
    price = pricecalc(symbol)
    qty = round(investment/price, right_rounding(Lotsize))
    return qty

def right_rounding(Lotsize):
#     print(Lotsize)
#     splitted = str(Lotsize).split('.') 
#     if float(splitted[0]) == 1:
#         return 0
#     else:
#         return len(splitted[1])
    decimal_places = 0
    while Lotsize < 1:
        Lotsize *= 10
        decimal_places += 1
    return decimal_places

# %%
quantitycalc('XRPUSDT', 100)
# Out:
# 221.4

# %%
right_rounding(1)
# Out:
# 0

# %% [markdown]
# ### Buy and Sell Function

# %%
def buy(investment):
    order = client.order_limit_buy(
        symbol=symbol,
        price=pricecalc(symbol),
        quantity=quantitycalc(symbol, investment)
    )
    print(order)
    pos_dict['in_position'] = True
    return order

def sell(qty):
    order = client.create_order(
        symbol=symbol,
        side='SELL',
        type='MARKET',
        quantity=qty
    )
    print(order)
    pos_dict['in_position'] = False

# %% [markdown]
# ### Checking buying signals & Position

# %%
pos_dict = {'in_position': False}

# %%
def checkbuy(investment):
    if not pos_dict['in_position']: 
        if df.Buy.values:
            return True
    else:
        print('already in a position')

# %% [markdown]
# ### Checking selling signals & Position

# %%
def checksell(order):
    order_status = client.get_order(symbol=symbol, orderId=order['orderId'])
    if pos_dict['in_position']:
        if order_status['status'] == 'NEW':
            print('Buy limit order pending')
        elif order_status['status'] == 'FILLED':
            cond1 = df.Close.values > float(order_status['price'])
            cond2 = pd.to_datetime('now') >= pd.to_datetime(order_status['updateTime'], unit='ms') + timedelta(minutes=150)
            if cond1 or cond2:
                sell(order_status['origQty'])
                print('Sell order executed')
    else:
        print('Currently not in position, no checks for selling')

# %% [markdown]
# ### Running the bot

# %%
investment = 100

while True:
    df = indicators(getdata(symbol))
    
    if checkbuy(investment):
        curr_order = buy(investment)
    try:
        checksell(curr_order)
    except:
        print('Not an order yet')
    
    time.sleep(60)
# Out:
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# Not an order yet
# {'symbol': 'BTCUSDT', 'orderId': 7704399, 'orderListId': -1, 'clientOrderId': '7GTMpioxDuW2CBSL8jsCui', 'transactTime': 1684614635410, 'price': '26221.90000000', 'origQty': '0.00381400', 'executedQty': '0.00000000', 'cummulativeQuoteQty': '0.00000000', 'status': 'NEW', 'timeInForce': 'GTC', 'type': 'LIMIT', 'side': 'BUY', 'workingTime': 1684614635410, 'fills': [], 'selfTradePreventionMode': 'NONE'}
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Buy limit order pending
# already in a position
# Not an order yet
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# already in a position
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# Not an order yet
# already in a position
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# Not an order yet
# already in a position
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# Not an order yet
# already in a position
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# Not an order yet
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\http\client.py in getresponse(self)
#    1321             try:
# -> 1322                 response.begin()
#    1323             except ConnectionError:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     769                 raise value.with_traceback(tb)
# --> 770             raise value
#     771         finally:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     448             raise
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     335         if isinstance(err, SocketTimeout):
# --> 336             raise ReadTimeoutError(
#     337                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='testnet.binance.vision', port=443): Read timed out. (read timeout=10)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19232/3299374531.py in <module>
#       2
#       3 while True:
# ----> 4     df = indicators(getdata(symbol))
#       5
#       6     if checkbuy(investment):
#
# ~\AppData\Local\Temp/ipykernel_19232/1863495402.py in getdata(symbol)
#       1 def getdata(symbol):
# ----> 2     frame = pd.DataFrame(client.get_historical_klines(symbol, '15m', '3000 minutes UTC'))
#       3     frame = frame.iloc[:, 0:5]
#       4     frame.columns = ['Time', 'Open', 'High', 'Low', 'Close']
#       5     frame = frame.set_index('Time')
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in get_historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#     982
#     983         """
# --> 984         return self._historical_klines(
#     985             symbol, interval, start_str=start_str, end_str=end_str, limit=limit, klines_type=klines_type
#     986         )
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in _historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#    1021         # establish first available start timestamp
#    1022         if start_ts is not None:
# -> 1023             first_valid_ts = self._get_earliest_valid_timestamp(symbol, interval, klines_type)
#    1024             start_ts = max(start_ts, first_valid_ts)
#    1025
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in _get_earliest_valid_timestamp(self, symbol, interval, klines_type)
#     952
#     953         """
# --> 954         kline = self._klines(
#     955             klines_type=klines_type,
#     956             symbol=symbol,
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in _klines(self, klines_type, **params)
#     931
#     932         if HistoricalKlinesType.SPOT == klines_type:
# --> 933             return self.get_klines(**params)
#     934         elif HistoricalKlinesType.FUTURES == klines_type:
#     935             return self.futures_klines(**params)
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in get_klines(self, **params)
#     916
#     917         """
# --> 918         return self._get('klines', data=params, version=self.PRIVATE_API_VERSION)
#     919
#     920     def _klines(self, klines_type: HistoricalKlinesType = HistoricalKlinesType.SPOT, **params) -> Dict:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in _get(self, path, signed, version, **kwargs)
#     412
#     413     def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# --> 414         return self._request_api('get', path, signed, version, **kwargs)
#     415
#     416     def _post(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs) -> Dict:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in _request_api(self, method, path, signed, version, **kwargs)
#     375     ):
#     376         uri = self._create_api_uri(path, signed, version)
# --> 377         return self._request(method, uri, signed, **kwargs)
#     378
#     379     def _request_futures_api(self, method, path, signed=False, **kwargs) -> Dict:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\binance\client.py in _request(self, method, uri, signed, force_params, **kwargs)
#     355         kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
#     356
# --> 357         self.response = getattr(self.session, method)(uri, **kwargs)
#     358         return self._handle_response(self.response)
#     359
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     598
#     599         kwargs.setdefault("allow_redirects", True)
# --> 600         return self.request("GET", url, **kwargs)
#     601
#     602     def options(self, url, **kwargs):
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     576                 raise SSLError(e, request=request)
#     577             elif isinstance(e, ReadTimeoutError):
# --> 578                 raise ReadTimeout(e, request=request)
#     579             elif isinstance(e, _InvalidHeader):
#     580                 raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='testnet.binance.vision', port=443): Read timed out. (read timeout=10)
